# %%
import pandas as pd

train = pd.read_csv('./data/Track1.train.csv', index_col=0)
train.head()
# Out:
# /Users/len/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                  order_id  order_total_num  order_amount  order_total_payment  \
# order_detail_id
# 1000000           1000000              1.0         239.9                 96.9
# 1001530           1001327              2.0         288.0                 96.9
# 1001531           1001327              2.0         288.0                 96.9
# 1001532           1001328              3.0         180.0                 89.7
# 1001533           1001329              1.0         159.9                 65.9
#
#                  order_total_discount       order_pay_time  order_status  \
# order_detail_id
# 1000000                           0.0  2012-11-01 00:10:56             6
# 1001530                           0.0  2013-08-31 23:14:42             6
# ...

# %%
train = train.sort_values(by='order_pay_time')
train.head()
# Out:
#                  order_id  order_total_num  order_amount  order_total_payment  \
# order_detail_id
# 3349677           2975399              1.0         199.0                 66.9
# 2042828           1890070              1.0         239.9                 96.9
# 2236278           2054851              1.0         199.0                 66.9
# 2278059           2090564              1.0         220.0                 75.8
# 2020196           1870788              1.0         199.0                 66.9
#
#                  order_total_discount       order_pay_time  order_status  \
# order_detail_id
# 3349677                           0.0  2012-11-01 00:00:07             1
# 2042828                           0.0  2012-11-01 00:00:14             6
# 2236278                           0.0  2012-11-01 00:00:21             6
# 2278059                           0.0  2012-11-01 00:00:24             6
# 2020196                           0.0  2012-11-01 00:01:02             6
#
# ...

# %%
train.tail()
# Out:
#                  order_id  order_total_num  order_amount  order_total_payment  \
# order_detail_id
# 2178824           2006121              4.0         389.6                187.6
# 2178825           2006121              4.0         389.6                187.6
# 2178826           2006121              4.0         389.6                187.6
# 2178827           2006121              4.0         389.6                187.6
# 1573422           1489244              1.0         199.0                 53.9
#
#                  order_total_discount       order_pay_time  order_status  \
# order_detail_id
# 2178824                           0.0  2013-08-31 23:59:46             6
# 2178825                           0.0  2013-08-31 23:59:46             6
# 2178826                           0.0  2013-08-31 23:59:46             6
# 2178827                           0.0  2013-08-31 23:59:46             6
# 1573422                           0.0  2013-08-31 23:59:59             6
#
# ...
