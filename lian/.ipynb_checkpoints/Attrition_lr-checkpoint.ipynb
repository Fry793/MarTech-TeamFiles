# %%
import pandas as pd

# %%
train = pd.read_csv('../Attrition/train.csv', index_col=0)
test = pd.read_csv('../Attrition/test.csv', index_col=0)

train.head()
# Out:
#          Age Attrition     BusinessTravel  DailyRate              Department  \
# user_id
# 1374      58        No      Travel_Rarely        605                   Sales
# 1092      45        No      Travel_Rarely        950  Research & Development
# 768       40        No      Travel_Rarely        300                   Sales
# 569       36        No         Non-Travel       1434                   Sales
# 911       25       Yes  Travel_Frequently        599                   Sales
#
#          DistanceFromHome  Education    EducationField  EmployeeCount  \
# user_id
# 1374                   21          3     Life Sciences              1
# 1092                   28          3  Technical Degree              1
# 768                    26          3         Marketing              1
# 569                     8          4     Life Sciences              1
# 911                    24          1     Life Sciences              1
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1176 entries, 1374 to 684
# Data columns (total 35 columns):
# Age                         1176 non-null int64
# Attrition                   1176 non-null object
# BusinessTravel              1176 non-null object
# DailyRate                   1176 non-null int64
# Department                  1176 non-null object
# DistanceFromHome            1176 non-null int64
# Education                   1176 non-null int64
# EducationField              1176 non-null object
# EmployeeCount               1176 non-null int64
# EmployeeNumber              1176 non-null int64
# EnvironmentSatisfaction     1176 non-null int64
# Gender                      1176 non-null object
# HourlyRate                  1176 non-null int64
# JobInvolvement              1176 non-null int64
# JobLevel                    1176 non-null int64
# JobRole                     1176 non-null object
# JobSatisfaction             1176 non-null int64
# ...

# %%
train['Attrition'] = train['Attrition'].map(lambda x : 1 if x =='Yes' else 0)
train.head()
# Out:
#          Age  Attrition     BusinessTravel  DailyRate              Department  \
# user_id
# 1374      58          0      Travel_Rarely        605                   Sales
# 1092      45          0      Travel_Rarely        950  Research & Development
# 768       40          0      Travel_Rarely        300                   Sales
# 569       36          0         Non-Travel       1434                   Sales
# 911       25          1  Travel_Frequently        599                   Sales
#
#          DistanceFromHome  Education    EducationField  EmployeeCount  \
# user_id
# 1374                   21          3     Life Sciences              1
# 1092                   28          3  Technical Degree              1
# 768                    26          3         Marketing              1
# 569                     8          4     Life Sciences              1
# 911                    24          1     Life Sciences              1
#
# ...

# %%
train = train.drop(['EmployeeNumber','StandardHours'], axis=1)
test = test.drop(['EmployeeNumber','StandardHours'], axis=1)
train.head()
# Out:
#          Age  Attrition     BusinessTravel  DailyRate              Department  \
# user_id
# 1374      58          0      Travel_Rarely        605                   Sales
# 1092      45          0      Travel_Rarely        950  Research & Development
# 768       40          0      Travel_Rarely        300                   Sales
# 569       36          0         Non-Travel       1434                   Sales
# 911       25          1  Travel_Frequently        599                   Sales
#
#          DistanceFromHome  Education    EducationField  EmployeeCount  \
# user_id
# 1374                   21          3     Life Sciences              1
# 1092                   28          3  Technical Degree              1
# 768                    26          3         Marketing              1
# 569                     8          4     Life Sciences              1
# 911                    24          1     Life Sciences              1
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

features = [
    'Age',
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'Over18',
    'OverTime'
]

for f in features:
    labelEncoder = LabelEncoder()
    train[f] = labelEncoder.fit_transform(train[f])
    test[f] = labelEncoder.transform(test[f])

train.head()
# Out:
#          Age  Attrition  BusinessTravel  DailyRate  Department  \
# user_id
# 1374      40          0               2        605           2
# 1092      27          0               2        950           1
# 768       22          0               2        300           2
# 569       18          0               0       1434           2
# 911        7          1               1        599           2
#
#          DistanceFromHome  Education  EducationField  EmployeeCount  \
# user_id
# 1374                   21          3               1              1
# 1092                   28          3               5              1
# 768                    26          3               2              1
# 569                     8          4               1              1
# 911                    24          1               1              1
#
#          EnvironmentSatisfaction  ...  PerformanceRating  \
# user_id                           ...
# ...

# %%
# train = train.drop(['YearsInCurrentRole', 'PerformanceRating'], axis=1)
# test = test.drop(['YearsInCurrentRole', 'PerformanceRating'], axis=1)

# %%
from sklearn.linear_model.logistic import LogisticRegression
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(
    train.drop('Attrition', axis=1), 
    train['Attrition'], 
    test_size=0.2, 
    random_state=42
)

# %%
model = LogisticRegression(
    max_iter=100,
    verbose=True,
    random_state=33,
    tol=1e-4,
)
model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/l.longfeng/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
# ...

# %%
predict = model.predict_proba(test)[:, 1]
# Out:
# array([0.11381855, 0.33720084, 0.23743899, 0.08701822, 0.34175775,
#        0.20511649, 0.0901124 , 0.07253059, 0.03188493, 0.22438963,
#        0.03210373, 0.331435  , 0.06243883, 0.13539117, 0.07314603,
#        0.09886416, 0.09182796, 0.12335792, 0.10816683, 0.27529899,
#        0.18136987, 0.02020183, 0.10509172, 0.18852508, 0.33718614,
#        0.09003974, 0.20375038, 0.05237771, 0.27244249, 0.14293577,
#        0.03583771, 0.04858258, 0.19441225, 0.06446395, 0.11711603,
#        0.04816983, 0.09110563, 0.19586488, 0.06233197, 0.28520406,
#        0.0555048 , 0.08777348, 0.0246706 , 0.02786252, 0.04790399,
#        0.23841862, 0.27644146, 0.04558507, 0.21455721, 0.19614019,
#        0.1075337 , 0.18232203, 0.11888966, 0.07765051, 0.15126211,
#        0.13100094, 0.1549989 , 0.1546055 , 0.13098346, 0.25179961,
#        0.06235576, 0.25733325, 0.05655026, 0.05138479, 0.28216963,
#        0.10461422, 0.12235726, 0.12027047, 0.12982801, 0.18698288,
# ...

# %%
test['Attrition']=predict
# test[['Attrition']].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-86b64cff0e1f> in <module>()
#       3 # test[['Attrition']].head()
#       4 from sklearn.metrics import roc_auc_score
# ----> 5 roc_auc_score(y_valid, predict)
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     388                                              max_fpr=max_fpr),
#     389                                      y_true, y_score, average,
# --> 390                                      sample_weight=sample_weight)
#     391     else:  # multilabel-indicator
#     392         return _average_binary_score(partial(_binary_roc_auc_score,
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
# ...

# %%
test[['Attrition']].to_csv('./Submission.csv')
